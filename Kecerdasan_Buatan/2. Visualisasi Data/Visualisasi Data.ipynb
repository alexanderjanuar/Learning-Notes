# %% [markdown]
# # Visualisasi Data

# %% [markdown]
# ### Content
# - Bar Plot
# - Line Plot
# - Pie Plot
# - Scatter Plot
# - Boxplot
# - Heatmap

# %% [markdown]
# ## Matplotlib
# **Matplotlib** adalah library **Python** yang fokus pada visualisasi data seperti plot grafik.

# %% [markdown]
# Install Library

# %%
# !pip install matplotlib
# Out:
# ...
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\user\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\user\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\user\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\user\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\user\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\user\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: You are using pip version 21.2.3; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Users\USER\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# Import Library

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Seaborn
# Seaborn adalah **library untuk membuat grafik dan statistik dengan menggunakan Python.** Library ini dibangun berdasarkan library Matplotlib yang sudah ada. Kemudian terintegrasi dengan struktur data pada Pandas.

# %% [markdown]
# Install Library

# %%
# !pip install seaborn

# %% [markdown]
# Import Library

# %%
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv("https://gist.githubusercontent.com/aishwarya8615/89d9f36fc014dea62487f7347864d16a/raw/8629d284e13976dcb13bb0b27043224b9266fffa/Life_Expectancy_Data.csv")
df.head()
# Out:
#        Country Continent  Year      Status  Life_expectancy   Adult_Mortality  \
# 0  Afghanistan      Asia  2015  Developing              65.0              263
# 1  Afghanistan      Asia  2014  Developing              59.9              271
# 2  Afghanistan      Asia  2013  Developing              59.9              268
# 3  Afghanistan      Asia  2012  Developing              59.5              272
# 4  Afghanistan      Asia  2011  Developing              59.2              275
#
#    infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  ...  Polio  \
# 0             62     0.01               71.279624         65.0  ...    6.0
# 1             64     0.01               73.523582         62.0  ...   58.0
# 2             66     0.01               73.219243         64.0  ...   62.0
# 3             69     0.01               78.184215         67.0  ...   67.0
# 4             71     0.01                7.097109         68.0  ...   68.0
#
# ...

# %% [markdown]
# ### A. Grafik Batang (Bar Plot)

# %%
#Dengan Matplotlib
continent_counts = df['Continent'].value_counts()

X = continent_counts.index
y = continent_counts

plt.figure(figsize=(15,10))
plt.bar(X,y)
plt.title("Jumlah Negara tiap Benua (Continents)", fontsize=16)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.barh(X,y)

plt.xlabel("Benua", fontsize=16)
plt.ylabel("Jumlah", fontsize=16)
plt.title("Jumlah Negara tiap Benua (Continents)", fontsize=16)
plt.show()

# %%
sns.set_theme()
plt.figure(figsize=(15,10))
sns.countplot(data=df, x="Continent",hue='Status')

plt.title("Jumlah Negara tiap Benua (Continents)", fontsize=16)
plt.show()

# %% [markdown]
# ### B. Grafik Garis
#
# Grafik garis umumnya digunakan untuk melihat perkembangan dari suatu nilai. Grafik garis digunakan bersama dengan tipe data yang bersifat date

# %%
dfFilter = df[df['Continent'] == 'Asia']
dfYear = dfFilter.groupby(['Year'])['Life_expectancy '].mean()
plt.figure(figsize=(15,10))

plt.plot(dfYear.index,dfYear,marker='o')
plt.xlabel("Tahun", fontsize=16)
plt.ylabel("Angka Harapan Hidup", fontsize=16)
plt.title("Perkembangan Angka Harapan Hidup", fontsize=16)
plt.show()

# %% [markdown]
# ### Grafik Pie
#
# Grafik Pie digunakan untuk membandingkan jumlah dari suatu nilai yang bersifat kategorical

# %%
data_pie =df['Status'].value_counts().rename_axis('Status').reset_index(name='Id_count')
data_pie
# Out:
#        Status  Id_count
# 0  Developing      2013
# 1   Developed       448

# %%
plt.figure(figsize=(10,10))
plt.pie(data_pie.Id_count, labels=data_pie["Status"], startangle=90,autopct='%.1f%%',explode = (0.1,0),shadow=True)
plt.title('Status Negara')
plt.show()

# %% [markdown]
# ### Grafik Scatter

# %% [markdown]
# Grafik scatter biasa digunakan untuk mengbandingkan antara 2 atribut yang bertipe numerik

# %%
plt.figure(figsize=(15,10))
plt.scatter(x= df['Life_expectancy '],y= df['GDP'])

plt.ylabel("GDP", fontsize=16)
plt.xlabel("Angka Harapan Hidup", fontsize=16)
plt.title("Perbandingan GDP dengan Angka Harapan Hidup", fontsize=16)
plt.show()

# %%
plt.figure(figsize=(18,10))
sns.scatterplot(data=df,x=df['Life_expectancy '],y=df['GDP'],hue="Status")

plt.ylabel("GDP", fontsize=16)
plt.xlabel("Angka Harapan Hidup", fontsize=16)
plt.title("Perbandingan GDP dengan Angka Harapan Hidup", fontsize=16)
plt.show()

# %% [markdown]
# ### Boxplot

# %% [markdown]
# Boxplot digunakan untuk melihat penyebaran dari suatu data yang bertipe kategorikal terhadap atribut yang bertipe data numerik
# (Categorical VS Numerik)

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=df,x='Status',y='Life_expectancy ')
plt.show()

# %% [markdown]
# # Heatmap

# %%
df.corr(numeric_only=True)
# Out:
#                                      Year  Life_expectancy   Adult_Mortality  \
# Year                             1.000000          0.166880        -0.073018
# Life_expectancy                  0.166880          1.000000        -0.685798
# Adult_Mortality                 -0.073018         -0.685798         1.000000
# infant_deaths                   -0.036840         -0.183986         0.065921
# Alcohol                         -0.150991          0.346108        -0.160048
# percentage_expenditure           0.037363          0.407029        -0.252149
# Hepatitis_B                      0.091357          0.239024        -0.143081
# Measles                         -0.093110         -0.148258         0.012939
#  BMI                             0.093375          0.578542        -0.384456
# under_five_deaths               -0.041873         -0.209363         0.080566
# Polio                            0.083819          0.456929        -0.256262
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(
    df.corr(numeric_only=True),
    annot=True, 
    cmap='flare', 
    annot_kws={'size':15},
    square=False)
# Out:
# <AxesSubplot: >
